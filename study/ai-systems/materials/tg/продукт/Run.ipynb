# %% [markdown]
# Пример имитации запуска сервиса из командной строки

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/D'
# Out:
# /content/drive/My Drive/D

# %%
# !python run.py --mode Hello
# Out:
# Что-нибудь
# Hello

# %%
# !python run.py --mode auto
# Out:
# Что-нибудь
# ['Iris-setosa' 'Iris-versicolor']
